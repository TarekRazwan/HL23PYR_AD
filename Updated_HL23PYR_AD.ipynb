# %%
import numpy as np
import matplotlib.pyplot as plt
from netpyne import sim, specs

# %matplotlib inline

savedata = 1 # Save Netpyne and BBP soma_voltage
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.

# %%
# !nrnivmodl mod/
# Out:
# /opt/miniconda3/envs/netpyne/bin/nrnivmodl:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import working_set
# /usr/bin/xcrun
# /Users/tarek/Desktop/HL23PYR_AD
# Mod files: "mod/mod//CaDynamics.mod" "mod/mod//Ca_HVA.mod" "mod/mod//Ca_LVA.mod" "mod/mod//Gfluct.mod" "mod/mod//Ih.mod" "mod/mod//Im.mod" "mod/mod//K_P.mod" "mod/mod//K_T.mod" "mod/mod//Kv3_1.mod" "mod/mod//NMDA.mod" "mod/mod//NaTg.mod" "mod/mod//Nap.mod" "mod/mod//ProbAMPANMDA.mod" "mod/mod//ProbUDFsyn.mod" "mod/mod//SK.mod" "mod/mod//epsp.mod" "mod/mod//tonic.mod"
#
#  -> Compiling mod_func.cpp
#  => LINKING shared library ./libnrnmech.dylib
# Successfully created x86_64/special

# %% [markdown]
# # **CONFIGURATION**

# %%
cfg = specs.SimConfig()

cfg.duration = 2350  # Total simulation time (ms)
cfg.dt = 0.025       # Integration step (ms)
cfg.seeds = {'cell': 4321, 'conn': 4321, 'stim': 1234, 'loc':4321}  
cfg.hParams = {'celsius': 34, 'v_init': -80}  
cfg.verbose = False
cfg.createNEURONObj = True
cfg.createPyStruct = True
cfg.cvode_active = False
cfg.cache_efficient = True

cfg.recordCells = ['HL23PYR_{}'.format(i) for i in range(1, 16)]  # Recording from all populations
cfg.recordTraces = {'V_soma': {'sec': 'soma_0', 'loc': 0.5, 'var': 'v'}}
cfg.recordStim = True
cfg.recordTime = True
cfg.recordStep = 0.025

cfg.simLabel = 'L23_Pyr'
cfg.saveFolder = '.'
cfg.savePickle = False
cfg.saveJson = False

# %% [markdown]
# # **NETWORK PARAMETERS**

# %%
netParams = specs.NetParams()

cellName = 'HL23PYR'
netParams.importCellParams(
    label=cellName, 
    conds={'cellType': cellName, 'cellModel': 'HH_full'},
    fileName='cellwrapper.py',  
    cellName='loadCell_' + cellName,
    cellInstance=True,
    cellArgs={'cellName': cellName, 'ad': True}  
)
# Out:
# NeuronTemplate_HL23PYR[0].axon[0](0.10) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[0](0.30) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[0](0.50) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[0](0.70) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[0](0.90) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[1](0.07) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[1](0.21) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[1](0.36) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[1](0.50) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[1](0.64) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[1](0.79) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[1](0.93) gbar_NaTg: 1.3800 → 1.6560
# NeuronTemplate_HL23PYR[0].axon[0](0.10) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[0](0.30) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[0](0.50) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[0](0.70) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[0](0.90) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[1](0.07) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[1](0.21) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[1](0.36) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[1](0.50) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[1](0.64) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[1](0.79) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].axon[1](0.93) gbar_Nap: 0.00842 → 0.01095
# NeuronTemplate_HL23PYR[0].soma[0](0.50) gbar_Kv3_1: 0.0424 → 0.0212
# NeuronTemplate_HL23PYR[0].soma[0](0.50) gbar_SK: 0.0008530 → 0.0005118
# NeuronTemplate_HL23PYR[0].dend[0](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[1](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[2](0.10) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[2](0.30) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[2](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[2](0.70) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[2](0.90) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[3](0.10) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[3](0.30) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[3](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[3](0.70) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[3](0.90) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[4](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[5](0.17) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[5](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[5](0.83) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[6](0.17) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[6](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[6](0.83) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[7](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[8](0.10) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[8](0.30) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[8](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[8](0.70) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[8](0.90) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[9](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[10](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[11](0.17) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[11](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[11](0.83) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[12](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[13](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[14](0.07) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[14](0.21) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[14](0.36) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[14](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[14](0.64) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[14](0.79) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[14](0.93) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[15](0.07) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[15](0.21) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[15](0.36) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[15](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[15](0.64) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[15](0.79) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[15](0.93) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[16](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[17](0.07) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[17](0.21) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[17](0.36) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[17](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[17](0.64) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[17](0.79) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[17](0.93) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[18](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[19](0.07) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[19](0.21) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[19](0.36) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[19](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[19](0.64) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[19](0.79) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[19](0.93) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[20](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[21](0.17) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[21](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[21](0.83) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[22](0.07) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[22](0.21) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[22](0.36) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[22](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[22](0.64) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[22](0.79) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[22](0.93) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[23](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[24](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[25](0.07) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[25](0.21) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[25](0.36) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[25](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[25](0.64) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[25](0.79) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[25](0.93) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[26](0.07) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[26](0.21) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[26](0.36) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[26](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[26](0.64) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[26](0.79) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[26](0.93) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[27](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[28](0.07) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[28](0.21) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[28](0.36) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[28](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[28](0.64) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[28](0.79) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[28](0.93) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[29](0.07) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[29](0.21) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[29](0.36) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[29](0.50) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[29](0.64) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[29](0.79) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0].dend[29](0.93) gbar_Ih: 7.09e-07 → 4.96e-07
# NeuronTemplate_HL23PYR[0]
# Kv3.1 gbar (soma): 0.0212
# SK gbar (soma): 0.0005118
# NaTg gbar (axon): 1.656
# Nap gbar (axon): 0.010946000000000001
# {conds: {cellType: 'HL23PYR', cellModel: 'HH_full'}, secs: {soma_0: {geom: {L: 12.583984375, nseg: 1, diam: 12.583999633789062, Ra: 100.0, cm: 1.0, pt3d: [(-6.2919921875, 0.0, 0.0, 12.583999633789062), (0.0, 0.0, 0.0, 12.583999633789062), (6.2919921875, 0.0, 0.0, 12.583999633789062)]}, topol: {}, mechs: {CaDynamics: {gamma: 0.0005, decay: 20.0, depth: 0.1, minCai: 0.0001}, Ca_HVA: {gbar: 0.00155}, Ca_LVA: {gbar: 0.00296}, Ih: {gbar: 0.000148, shift1: 154.9, shift2: 11.9, shift3: 0.0, shift4: 33.1, shift5: 6.43, shift6: 193.0}, Im: {gbar: 0.000306}, K_P: {gbar: 0.000208}, K_T: {gbar: 0.0605}, Kv3_1: {gbar: 0.0212}, NaTg: {gbar: 0.272, vshifth: 15.0, vshiftm: 13.0, slopeh: 6.0, slopem: 7.0}, SK: {gbar: 0.0005118}, pas: {g: 9.54e-05, e: -80.0}}, ions: {ca: {e: 132.4579341637009, i: 5e-05, o: 2.0}, k: {e: -85.0, i: 54.4, o: 2.5}, na: {e: 50.0, i: 10.0, o: 140.0}}}, dend_0: {geom: {L: 23.139970025287568, nseg: 1, diam: 1.0838482132377645, Ra: 100.0, cm: 2.0, pt3d: [(-1.24688720703125, 6.9302978515625, -0.033298492431640625, 1.2355999946594238), (-1.66571044921875, 7.99432373046875, -0.0467987060546875, 1.2208000421524048), (-2.223876953125, 8.9849853515625, -0.06639862060546875, 1.2059999704360962), (-2.307373046875, 10.12548828125, -0.09239959716796875, 1.1914000511169434), (-2.31317138671875, 11.26947021484375, -0.12459945678710938, 1.176800012588501), (-2.38409423828125, 12.40667724609375, -0.17279815673828125, 1.1619999408721924), (-2.26171875, 13.519775390625, -0.2637977600097656, 1.1471999883651733), (-2.58428955078125, 14.597412109375, -0.3819007873535156, 1.132599949836731), (-2.6632080078125, 15.73797607421875, -0.4549980163574219, 1.1180000305175781), (-2.6632080078125, 16.87738037109375, -0.4656982421875, 1.1030000448226929), (-2.6632080078125, 18.0042724609375, -0.38330078125, 1.0884000062942505), (-2.72039794921875, 19.13568115234375, -0.2848014831542969, 1.073799967765808), (-2.97100830078125, 20.235107421875, -0.13359832763671875, 1.0592000484466553), (-3.199798583984375, 21.322998046875, 0.04199981689453125, 1.0441999435424805), (-3.302703857421875, 22.3411865234375, 0.14640045166015625, 1.0296000242233276), (-3.57269287109375, 23.2471923828125, 0.01850128173828125, 1.0149999856948853), (-4.524505615234375, 23.668212890625, -0.17749786376953125, 1.0), (-5.5758056640625, 23.7838134765625, -0.18539810180664062, 0.9854000210762024), (-5.88360595703125, 24.716064453125, -0.18729782104492188, 0.97079998254776), (-5.86639404296875, 25.809814453125, -0.20689773559570312, 0.9562000036239624), (-5.878997802734375, 26.8817138671875, 0.0381011962890625, 0.9412000179290771), (-5.91900634765625, 27.8026123046875, 0.6118011474609375, 0.9265999794006348)]}, topol: {parentSec: 'soma_0', parentX: 0.5, childX: 0.0}, mechs: {Ih: {gbar: 4.963e-07, shift1: 154.9, shift2: 11.9, shift3: 0.0, shift4: 33.1, shift5: 6.43, shift6: 193.0}, pas: {g: 9.54e-05, e: -80.0}}}, dend_1: {geom: {L: 19.46868612379019, nseg: 1, diam: 0.7587521135639547, Ra: 100.0, cm: 2.0, pt3d: [(-5.91900634765625, 27.8026123046875, 0.6118011474609375, 0.9265999794006348), (-5.945404052734375, 27.8507080078125, 1.1753997802734375, 0.9265999794006348), (-6.4578857421875, 28.51080322265625, 1.9449005126953125, 0.9046000242233276), (-7.437103271484375, 28.9019775390625, 2.7378005981445312, 0.8830000162124634), (-8.274505615234375, 29.61236572265625, 3.3818016052246094, 0.8610000014305115), (-8.6029052734375, 30.68206787109375, 3.8659019470214844, 0.8392000198364258), (-8.71038818359375, 31.81011962890625, 4.260200500488281, 0.8172000050544739), (-8.82940673828125, 32.82940673828125, 4.746002197265625, 0.7954000234603882), (-8.881988525390625, 33.84979248046875, 5.2891998291015625, 0.7735999822616577), (-9.308685302734375, 34.82110595703125, 5.81610107421875, 0.7516000270843506), (-10.2913818359375, 35.1654052734375, 6.301399230957031, 0.7296000123023987), (-11.37939453125, 35.37249755859375, 6.772899627685547, 0.7080000042915344), (-11.604705810546875, 36.3563232421875, 7. ...

# %% [markdown]
# ## *Apply_AD_changes*

# %%
def apply_AD_changes(cell):
    print("\Applying AD-related ion channel modifications")

def check_AD_channels(cell):
    channels = [
        ("soma", "gbar_Kv3_1"),
        ("soma", "gbar_SK"),
        ("axon", "gbar_NaTg"),
        ("axon", "gbar_Nap"),
        ("basal", "gbar_Ih"),
    ]

    for sec_type, channel in channels:
        print(f"\n📍 Checking {channel} in {sec_type}")
        found = False

        # Dynamically pull the section list (e.g., cell.axon)
        sec_list = getattr(cell, sec_type, [])

        for sec in sec_list:
            for seg in sec:
                if hasattr(seg, channel):
                    val = getattr(seg, channel)
                    print(f"  {sec.name()}({seg.x:.2f}): {val}")
                    found = True

        if not found:
            print(f"  ⚠️ {channel} not found in {sec_type}")

# %%
from cellwrapper import loadCell_HL23PYR
cell = loadCell_HL23PYR("HL23PYR")


# Apply AD-related ion channel modifications
apply_AD_changes(cell)

# Check that changes were applied
check_AD_channels(cell)
# Out:
# NEURON: NeuronTemplate_HL23PYR : a template cannot be redefined
#  in models/NeuronTemplate_HL23PYR.hoc near line 1
#  begintemplate NeuronTemplate_HL23PYR
#                                     ^
#         xopen("models/Neu...")
# NeuronTemplate_HL23PYR[0]
# Kv3.1 gbar (soma): 0.0424
# SK gbar (soma): 0.000853
# NaTg gbar (axon): 1.38
# Nap gbar (axon): 0.00842
# \Applying AD-related ion channel modifications
#
# 📍 Checking gbar_Kv3_1 in soma
#   NeuronTemplate_HL23PYR[0].soma[0](0.50): 0.0424
#
# 📍 Checking gbar_SK in soma
#   NeuronTemplate_HL23PYR[0].soma[0](0.50): 0.000853
#
# 📍 Checking gbar_NaTg in axon
#   NeuronTemplate_HL23PYR[0].axon[0](0.10): 1.38
#   NeuronTemplate_HL23PYR[0].axon[0](0.30): 1.38
#   NeuronTemplate_HL23PYR[0].axon[0](0.50): 1.38
#   NeuronTemplate_HL23PYR[0].axon[0](0.70): 1.38
#   NeuronTemplate_HL23PYR[0].axon[0](0.90): 1.38
#   NeuronTemplate_HL23PYR[0].axon[1](0.07): 1.38
#   NeuronTemplate_HL23PYR[0].axon[1](0.21): 1.38
#   NeuronTemplate_HL23PYR[0].axon[1](0.36): 1.38
#   NeuronTemplate_HL23PYR[0].axon[1](0.50): 1.38
#   NeuronTemplate_HL23PYR[0].axon[1](0.64): 1.38
#   NeuronTemplate_HL23PYR[0].axon[1](0.79): 1.38
#   NeuronTemplate_HL23PYR[0].axon[1](0.93): 1.38
#
# 📍 Checking gbar_Nap in axon
#   NeuronTemplate_HL23PYR[0].axon[0](0.10): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[0](0.30): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[0](0.50): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[0](0.70): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[0](0.90): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[1](0.07): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[1](0.21): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[1](0.36): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[1](0.50): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[1](0.64): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[1](0.79): 0.00842
#   NeuronTemplate_HL23PYR[0].axon[1](0.93): 0.00842
#
# 📍 Checking gbar_Ih in basal
#   NeuronTemplate_HL23PYR[0].dend[0](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[1](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[2](0.10): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[2](0.30): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[2](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[2](0.70): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[2](0.90): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[3](0.10): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[3](0.30): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[3](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[3](0.70): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[3](0.90): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[4](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[5](0.17): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[5](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[5](0.83): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[6](0.17): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[6](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[6](0.83): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[7](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[8](0.10): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[8](0.30): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[8](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[8](0.70): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[8](0.90): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[9](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[10](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[11](0.17): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[11](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[11](0.83): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[12](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[13](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[14](0.07): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[14](0.21): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[14](0.36): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[14](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[14](0.64): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[14](0.79): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[14](0.93): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[15](0.07): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[15](0.21): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[15](0.36): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[15](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[15](0.64): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[15](0.79): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[15](0.93): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[16](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[17](0.07): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[17](0.21): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[17](0.36): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[17](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[17](0.64): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[17](0.79): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[17](0.93): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[18](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[19](0.07): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[19](0.21): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[19](0.36): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[19](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[19](0.64): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[19](0.79): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[19](0.93): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[20](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[21](0.17): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[21](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[21](0.83): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[22](0.07): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[22](0.21): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[22](0.36): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[22](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[22](0.64): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[22](0.79): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[22](0.93): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[23](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[24](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[25](0.07): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[25](0.21): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[25](0.36): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[25](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[25](0.64): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[25](0.79): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[25](0.93): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[26](0.07): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[26](0.21): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[26](0.36): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[26](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[26](0.64): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[26](0.79): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[26](0.93): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[27](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[28](0.07): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[28](0.21): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[28](0.36): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[28](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[28](0.64): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[28](0.79): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[28](0.93): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[29](0.07): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[29](0.21): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[29](0.36): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[29](0.50): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[29](0.64): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[29](0.79): 7.09e-07
#   NeuronTemplate_HL23PYR[0].dend[29](0.93): 7.09e-07

# %% [markdown]
# # *Add Background Excitatory Synaptic Input*

# %%
# netParams.stimSourceParams['exc_bg'] = {
#     'type': 'NetStim',
#     'rate': 2000,  # Hz, controls the frequency of random excitatory synapses
#     'start': 0, 
#     'noise': 1.0  # 1.0 means Poisson-distributed spike times
# }

# netParams.stimTargetParams['exc_bg->HL23PYR'] = {
#     'source': 'exc_bg', 
#     'conds': {'pop': 'HL23PYR'},
#     'sec': 'soma_0', 
#     'loc': 0.5, 
#     'weight': 0.001,  # Synaptic weight (adjust this!)
#     'delay': 1,
#     'synMech': 'AMPA'  # Use an AMPA-like mechanism
# }

# %% [markdown]
# # *Add Background Inhibitory Synaptic Input*

# %%
# netParams.stimSourceParams['inh_bg'] = {
#     'type': 'NetStim',
#     'rate': 1000,  # Hz, inhibitory input rate
#     'start': 0, 
#     'noise': 1.0
# }

# netParams.stimTargetParams['inh_bg->HL23PYR'] = {
#     'source': 'inh_bg', 
#     'conds': {'pop': 'HL23PYR'},
#     'sec': 'soma_0', 
#     'loc': 0.5, 
#     'weight': 0.002,  # Typically stronger than AMPA
#     'delay': 1,
#     'synMech': 'GABA'  # Use a GABA-like mechanism
# }

# %% [markdown]
# # **POPULATIONS & CURRENT INJECTIONS**

# %%
allpops = ['HL23PYR_{}'.format(i) for i in range(1, 16)]

for popName in allpops:
    netParams.popParams[popName] = {'cellType': cellName, 'cellModel': 'HH_full', 'numCells': 1}

cfg.IClamp = []
current_start = -0.3  # Initial current (nA)
current_end = 0.4  # Final current (nA)
current_step = 0.050  # Step size (nA)

# Define stimulation
cfg.IClampnumber = 0
for i, popName in enumerate(allpops):
    amp = current_start + i * current_step
    cfg.IClamp.append({'pop': popName, 'sec': 'soma_0', 'loc': 0.5, 'start': 1200, 'dur': 800, 'amp': amp})  
    cfg.IClampnumber += 1

# Assign stimulation to each population
for j in range(cfg.IClampnumber):
    key = 'IClamp{}'.format(j+1)
    params = cfg.IClamp[j]
    pop, sec, loc, start, dur, amp = params['pop'], params['sec'], params['loc'], params['start'], params['dur'], params['amp']
    
    netParams.stimSourceParams[key] = {'type': 'IClamp', 'delay': start, 'dur': dur, 'amp': amp}
    netParams.stimTargetParams[key+'_'+pop] = {'source': key, 'conds': {'pop': pop}, 'sec': sec, 'loc': loc}

# %% [markdown]
# ## *Define AD Stage & Reduce AMPA/NMDA Conductance*

# %%
# netParams.synMechParams['ProbAMPANMDA'] = {
#     'mod': 'ProbAMPANMDA'  # Uses MOD mechanism
# }

# # Define AD stage (0 = Healthy, 1 = Early AD, 2 = Late AD)
# AD_stage = 0  # Change this to 2 for Late AD

# # Default Healthy values
# gmax_values = {
#     'AMPA': 0.001,  # Healthy AMPA
#     'NMDA': 0.001   # Healthy NMDA
# }

# # Apply Alzheimer’s Disease modifications
# if AD_stage == 1:  # Early AD (Mild Synaptic Loss)
#     gmax_values['AMPA'] = 0.0008  # Reduce AMPA by 20%
#     gmax_values['NMDA'] = 0.0007  # Reduce NMDA by 30%
# elif AD_stage == 2:  # Late AD (Severe Synaptic Failure)
#     gmax_values['AMPA'] = 0.0004  # Reduce AMPA by 60%
#     gmax_values['NMDA'] = 0.0003  # Reduce NMDA by 70%

# # Assign the updated gmax values in NetPyNE
# netParams.synMechParams['ProbAMPANMDA']['gmax'] = gmax_values['AMPA']

# %% [markdown]
# ## *Apply Leak, Adaptation, and Ih Conductances*

# %%
# # Ensure conductances are applied to all sections
# for sec_name in netParams.cellParams['HL23PYR']['secs']:
#     netParams.cellParams['HL23PYR']['secs'][sec_name]['mechs'] = {}

#     # Passive leak conductance
#     netParams.cellParams['HL23PYR']['secs'][sec_name]['mechs']['pas'] = {
#         'g': 9.54e-05,  # Leak conductance
#         'e': -70  # Leak reversal potential
#     }

#     # M-type potassium current (I_M)
#     netParams.cellParams['HL23PYR']['secs'][sec_name]['mechs']['Im'] = {
#         'gbar': 0.000306
#     }

#     # After-hyperpolarization current (I_AHP)
#     netParams.cellParams['HL23PYR']['secs'][sec_name]['mechs']['SK'] = {
#         'gbar': 0.000853
#     }

#     # Hyperpolarization-activated cation current (Ih)
#     netParams.cellParams['HL23PYR']['secs'][sec_name]['mechs']['Ih'] = {
#         'gbar': 0.000148
#     }

# %% [markdown]
# # **RUN SIMULATION**

# %%
sim.initialize(simConfig=cfg, netParams=netParams)
sim.net.createPops()
sim.net.createCells()
sim.net.connectCells()
sim.net.addStims()
sim.setupRecording()

sim.runSim()                      			# run parallel Neuron simulation  
sim.gatherData()                  			# gather spiking data and cell info from each node
sim.saveData()                    			# save params, cell info and sim output to file (pickle,mat,txt,etc)#
sim.analysis.plotData()         			# plot spike raster etc
sim.analysis.plotShape()
# Out:
# Start time:  2025-04-02 15:02:50.905837
#
# Creating network of 15 cell populations on 1 hosts...
#   Number of cells on node 0: 15
#   Done; cell creation time = 0.36 s.
# Making connections...
#   Number of connections on node 0: 0
#   Done; cell connection time = 0.00 s.
# Adding stims...
#   Number of stims on node 0: 15
#   Done; cell stims creation time = 0.00 s.
# Recording 30 traces of 2 types on node 0
#
# Running simulation using NEURON for 2350.0 ms...
#   Done; run time = 42.30 s; real-time ratio: 0.06.
#
# Gathering data...
#   Done; gather time = 0.22 s.
#
# Analyzing...
#   Cells: 15
#   Connections: 0 (0.00 per cell)
#   Spikes: 99 (2.81 Hz)
#   Simulated time: 2.4 s; 1 workers
#   Run time: 42.30 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
#   Done; plotting time = 0.00 s
#
# Total time = 42.90 s
# Plotting 3D cell shape ...
# (<Figure size 640x480 with 1 Axes>, {})

# %%
# import numpy as np

# # If time is missing, reconstruct it manually
# time = np.arange(0, cfg.duration, cfg.dt)
# print(f"Reconstructed time array (first 10 values): {time[:10]}")

# %% [markdown]
# # **ANALYSIS: Firing Rate Calculation**

# %%
# Extract firing rate
spk_times = sim.simData['spkt']  # Spike Times
spk_ids = sim.simData['spkid']  # Neuron IDs

steps, rates = np.unique(spk_ids, return_counts=True)

# %% [markdown]
# # **PLOT: F-I Curve**

# %%
from scipy.stats import linregress

# Ensure current_start is correctly defined before running regression
current_start = -0.30  # nA (example, adjust as needed)
current_step = 0.050  # nA step

# Compute linear regression on the F-I curve
slope, intercept, r_value, p_value, std_err = linregress(current_start + steps * current_step, rates / 0.8)

print(f"F-I Curve Slope: {slope:.3f} Hz/nA")
print(f"Intercept: {intercept:.3f} Hz")
print(f"R-squared: {r_value**2:.3f}")
# Out:
# F-I Curve Slope: 46.726 Hz/nA
# Intercept: 4.955 Hz
# R-squared: 0.954

# %%
# Plot
plt.figure(figsize=(8, 4))
plt.plot(current_start + steps * current_step, rates/0.8, marker='o', label='Firing Rate')
plt.plot([0.1,0.4],[7.054 + 0.1*44.643, 7.054 + 0.4*44.643],'r', label='linregress')
plt.xlabel('Injected Current (nA)')
plt.ylabel('Firing rate (spikes/s)')
plt.title('Firing Rate vs Injected Current')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## *Extract Rheobase*

# %%
import numpy as np

# Extract spike times and IDs
spike_times = np.array(sim.simData['spkt'])  # Spike times
spike_ids = np.array(sim.simData['spkid'])  # Corresponding cell IDs

# Define current steps 
current_steps = np.arange(-300, 400, 50)  # pA

# Identify the first current step that reliably produces a spike
for i, current in enumerate(current_steps):
    spikes_at_current = np.any(spike_ids == i)  # Check if any cell spikes at this current
    if spikes_at_current:
        rheobase = current
        break

print(f"Rheobase: {rheobase} pA")
# Out:
# Rheobase: 50 pA

# %% [markdown]
# # **PLOT: V-I Curve (Sag)**

# %%
# Compute Sag Values for each cell
sag_values = []

for cell in sim.simData['V_soma']:
    V_soma = np.array(sim.simData['V_soma'][cell])  # Convert to NumPy array
    t = np.array(sim.simData['t'])  # Time array

    # Define hyperpolarization window
    V_min = V_soma[(t >= 1200) & (t < 2000)].min()  # Minimum voltage during hyperpolarization
    V_ss = V_soma[t <= 2000][-1]  # Steady-state voltage

    sag = V_ss - V_min
    sag_values.append(sag)

# Now `sag_values` exists, so you can iterate over it
for i, amp in enumerate(np.linspace(-0.300, 0.0, 7)):
    print(f"Injected Current: {amp:.3f} nA | Sag: {sag_values[i]:.3f} mV")
# Out:
# Injected Current: -0.300 nA | Sag: 3.212 mV
# Injected Current: -0.250 nA | Sag: 2.464 mV
# Injected Current: -0.200 nA | Sag: 1.790 mV
# Injected Current: -0.150 nA | Sag: 1.202 mV
# Injected Current: -0.100 nA | Sag: 0.711 mV
# Injected Current: -0.050 nA | Sag: 0.316 mV
# Injected Current: 0.000 nA | Sag: 0.000 mV

# %%
plt.figure(figsize=(8, 4))
plt.grid(True)

plt.plot(np.linspace(-0.300, 0.0, 7), sag_values[0:7], 'o-')

plt.ylabel('Sag (mV)')
plt.xlabel('External Current (nA)')
plt.title("V-I Curve (Sag)")
plt.grid(True)
plt.show()

# %% [markdown]
# # **PLOT: Voltage Traces**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 4))

# Define time range
start_time, end_time = 1000, 3000

# Convert time array to NumPy for indexing
time_array = np.array(sim.simData['t'])

# Find indices corresponding to the desired time range
time_indices = np.where((time_array >= start_time) & (time_array <= end_time))

# Plot voltage traces for all cells in the given time range
for cellName in sim.simData['V_soma'].keys():
    plt.plot(time_array[time_indices], np.array(sim.simData['V_soma'][cellName])[time_indices], label=f"Cell {cellName}")

plt.xlabel('Time (ms)')
plt.ylabel('Voltage (mV)')
plt.title(f'Voltage Traces ({start_time}-{end_time} ms)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 4))
cellName = list(sim.simData['V_soma'].keys())[10]  # Select the first cell
plt.plot(sim.simData['t'], sim.simData['V_soma'][cellName], label=f"Cell {cellName}")
plt.xlabel('Time (ms)')
plt.ylabel('Voltage (mV)')
plt.title('Voltage Trace for One Cell')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # ***PHYSIOLOGICAL PROPERTIES EFEL: https://efel.readthedocs.io/en/latest/eFeatures.html ***

# %%
# !pip install efel
import efel

# %%
traces = []
for cellName in sim.simData['V_soma'].keys():
    # plt.plot(sim.simData['t'], sim.simData['V_soma'][cellName], label=f"Cell {cellName}")

    trace = {}
    trace['T'] = sim.simData['t']
    trace['V'] = sim.simData['V_soma'][cellName]
    trace['stim_start'] = [1200.0]
    trace['stim_end'] = [2000.0]
    traces.append(trace)

#plt.xlim(1000,2200)

# %%
feature_items = ['sag_amplitude', 'steady_state_voltage_stimend','spike_count','mean_frequency', 'ISI_CV', 'time_to_first_spike', 'time_to_second_spike', 'AP_height', 'AP_width', 'AP_duration_half_width', 'AP_amplitude']
feature_values = efel.get_feature_values(traces, feature_items)

# %%
# feature_values[0], '  ', feature_values[-1]

# %%
# attributes = dir(feature_values)
# print(attributes)

# %%
# Compute Sag Values for each cell
sag_values = []

for step_number in range(0,6):
    sag_values.append(feature_values[step_number]['sag_amplitude'])

plt.figure(figsize=(8, 4))
plt.grid(True)
plt.plot(np.linspace(-0.300, 0.0, 6), sag_values[0:6], 'o-')

plt.ylabel('Sag (mV)')
plt.xlabel('External Current (nA)')
plt.title("V-I Curve (Sag)")
plt.grid(True)
plt.show()

# %%
# Compute steady_state_voltage_stimend Values for each cell
values = []

for step_number in range(0,6):
    values.append(feature_values[step_number]['steady_state_voltage_stimend'])

plt.figure(figsize=(8, 4))
plt.grid(True)
plt.plot(np.linspace(-0.300, 0.0, 6), values[0:6], 'o-')

plt.ylabel('steady_state_voltage_stimend (mV)')
plt.xlabel('External Current (nA)')
plt.title("V-I Curve (steady_state_voltage_stimend)")
plt.grid(True)
plt.show()

# %%
# Compute AP_duration_half_width Values for each cell
values = []
values_mean = []
values_std = []

plt.figure(figsize=(8, 4))
plt.grid(True)

for step_number in range(8,15):
    values.append(feature_values[step_number]['AP_duration_half_width'][0]) # first
    values_mean.append(np.mean(feature_values[step_number]['AP_duration_half_width']))
    values_std.append(np.std(feature_values[step_number]['AP_duration_half_width']))

    # plt.plot(np.zeros(len(feature_values[step_number]['AP_duration_half_width'])) + -0.30+step_number*0.05,feature_values[step_number]['AP_duration_half_width'], 'ro')

plt.errorbar(np.linspace(0.100, 0.4, 7), values_mean[0:7], yerr=values_std[0:7],  color='b', ecolor='b', label="Mean ± Std Dev", elinewidth = 2.0)
plt.ylabel('AP_duration_half_width (ms)')
plt.xlabel('External Current (nA)')
plt.title("AP_duration_half_width")
plt.grid(True)
plt.show()

# %%
# Compute AP_amplitude Values for each cell
values = []
values_mean = []
values_std = []

plt.figure(figsize=(8, 4))
plt.grid(True)

for step_number in range(8,15):
    values.append(feature_values[step_number]['AP_amplitude'][0]) # first
    values_mean.append(np.mean(feature_values[step_number]['AP_amplitude']))
    values_std.append(np.std(feature_values[step_number]['AP_amplitude']))

    plt.plot(np.zeros(len(feature_values[step_number]['AP_amplitude'])) + -0.30+step_number*0.05,feature_values[step_number]['AP_amplitude'], 'ro')

plt.errorbar(np.linspace(0.100, 0.4, 7), values_mean[0:7], yerr=values_std[0:7],  color='b', ecolor='b', label="Mean ± Std Dev", elinewidth = 2.0)
plt.ylabel('AP_amplitude (ms)')
plt.xlabel('External Current (nA)')
plt.title("AP_amplitude")
plt.grid(True)
plt.show()
